# %% [markdown]
# **Import Packages**

# %%
# !pip install uv
# !uv pip uninstall torch torchvision torchaudio --system
# Out:
# Collecting uv
#   Downloading uv-0.4.30-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.4.30-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 21.9 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.4.30
# Using Python 3.10.12 environment at /usr
# Uninstalled 3 packages in 1.04s
#  - torch==2.5.0+cu121 (from https://download.pytorch.org/whl/cu121_full/torch-2.5.0%2Bcu121-cp310-cp310-linux_x86_64.whl)
#  - torchaudio==2.5.0+cu121 (from https://download.pytorch.org/whl/cu121_full/torchaudio-2.5.0%2Bcu121-cp310-cp310-linux_x86_64.whl)
#  - torchvision==0.20.0+cu121 (from https://download.pytorch.org/whl/cu121_full/torchvision-0.20.0%2Bcu121-cp310-cp310-linux_x86_64.whl)

# %%
# !uv pip install torch==2.3.0 --system -f https://download.pytorch.org/whl/cpu
# !uv pip install torch_sparse==0.6.18+pt23cpu pyg_lib==0.4.0+pt23cpu --system -f https://data.pyg.org/whl/torch-2.3.0+cpu.html
# Out:
# Streaming output truncated to the last 5000 lines.
# nvidia-cusolver-cu12 ------------------------------ 34.65 MiB/118.41 MiB
# triton     ------------------------------ 33.66 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 34.49 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 33.64 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 34.39 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 34.17 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 34.72 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 34.77 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 35.02 MiB/118.41 MiB
# triton     ------------------------------ 33.83 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 34.70 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 33.99 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 34.69 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 34.51 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 35.14 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 35.12 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 35.22 MiB/118.41 MiB
# triton     ------------------------------ 33.84 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 35.07 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 34.18 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 34.70 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 34.72 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 35.31 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 35.33 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 35.41 MiB/118.41 MiB
# triton     ------------------------------ 34.20 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 35.25 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 34.37 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 35.06 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 34.89 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 35.70 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 35.53 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 35.61 MiB/118.41 MiB
# triton     ------------------------------ 34.57 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 35.44 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 34.67 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 35.23 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 35.08 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 35.90 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 35.72 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 35.83 MiB/118.41 MiB
# triton     ------------------------------ 34.76 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 35.62 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 34.92 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 35.61 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 35.25 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 36.05 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 36.09 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 36.16 MiB/118.41 MiB
# triton     ------------------------------ 34.98 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 36.01 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 35.10 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 35.81 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 35.61 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 36.25 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 36.47 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 36.50 MiB/118.41 MiB
# triton     ------------------------------ 35.15 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 36.40 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 35.36 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 36.01 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 35.81 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 36.62 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 36.67 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 36.72 MiB/118.41 MiB
# triton     ------------------------------ 35.51 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 36.61 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 35.67 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 36.36 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 36.17 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 36.81 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 36.86 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 36.91 MiB/118.41 MiB
# triton     ------------------------------ 35.86 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 36.99 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 35.85 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 36.77 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 36.55 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 37.33 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 37.24 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 37.42 MiB/118.41 MiB
# triton     ------------------------------ 36.22 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 37.18 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 36.17 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 37.16 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 36.92 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 37.72 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 37.59 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 37.85 MiB/118.41 MiB
# triton     ------------------------------ 36.61 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 37.56 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 36.57 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 37.35 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 37.30 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 38.11 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 38.00 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 38.03 MiB/118.41 MiB
# triton     ------------------------------ 36.95 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 37.90 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 36.95 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 37.91 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 37.66 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 38.33 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 38.48 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 38.61 MiB/118.41 MiB
# triton     ------------------------------ 37.14 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 38.48 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 37.45 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 38.12 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 37.99 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 38.64 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 38.76 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 38.78 MiB/118.41 MiB
# triton     ------------------------------ 37.54 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 38.64 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 37.64 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 38.52 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 38.19 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 38.87 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 38.97 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 39.00 MiB/118.41 MiB
# triton     ------------------------------ 37.92 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 38.83 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 37.83 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 38.72 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 38.45 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 39.25 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 39.34 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 39.39 MiB/118.41 MiB
# triton     ------------------------------ 38.06 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 39.20 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 38.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 39.06 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 38.75 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 39.45 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 39.50 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 39.58 MiB/118.41 MiB
# triton     ------------------------------ 38.32 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 39.57 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 38.40 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 39.45 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 38.92 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 39.83 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 39.87 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 39.95 MiB/118.41 MiB
# triton     ------------------------------ 38.71 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 39.76 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 38.72 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 39.62 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 39.45 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 40.20 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 40.24 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 40.14 MiB/118.41 MiB
# triton     ------------------------------ 39.11 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 40.10 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 38.90 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 39.98 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 39.65 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 40.37 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 40.43 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 40.55 MiB/118.41 MiB
# triton     ------------------------------ 39.28 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 40.34 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 39.31 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 40.17 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 39.84 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 40.58 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 40.61 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 40.72 MiB/118.41 MiB
# triton     ------------------------------ 39.69 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 40.62 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 39.68 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 40.36 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 40.03 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 40.97 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 40.99 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 41.09 MiB/118.41 MiB
# triton     ------------------------------ 39.87 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 40.80 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 39.86 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 40.74 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 40.40 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 41.36 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 41.38 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 41.47 MiB/118.41 MiB
# triton     ------------------------------ 40.24 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 41.27 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 40.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 40.94 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 40.79 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 41.73 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 41.74 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 41.84 MiB/118.41 MiB
# triton     ------------------------------ 40.60 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 41.47 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 40.56 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 41.30 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 41.10 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 42.02 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 41.91 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 42.24 MiB/118.41 MiB
# triton     ------------------------------ 40.98 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 42.02 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 40.90 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 41.86 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 41.52 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 42.51 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 42.39 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 42.59 MiB/118.41 MiB
# triton     ------------------------------ 41.39 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 42.38 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 41.31 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 42.24 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 41.89 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 42.89 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 42.83 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 42.97 MiB/118.41 MiB
# triton     ------------------------------ 41.75 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 42.59 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 41.65 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 42.61 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 42.12 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 43.30 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 43.16 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 43.34 MiB/118.41 MiB
# triton     ------------------------------ 42.15 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 43.16 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 42.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 42.98 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 42.67 MiB/697.83 MiB
# ⠼ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 43.69 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 43.36 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 43.73 MiB/118.41 MiB
# triton     ------------------------------ 42.52 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 43.54 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 42.22 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 43.17 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 43.04 MiB/697.83 MiB
# ⠼ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 43.86 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 43.91 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 44.09 MiB/118.41 MiB
# triton     ------------------------------ 42.72 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 43.87 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 42.56 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 43.74 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 43.41 MiB/697.83 MiB
# ⠼ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 44.48 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 44.30 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 44.47 MiB/118.41 MiB
# triton     ------------------------------ 43.24 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 44.30 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 42.94 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 44.09 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 43.77 MiB/697.83 MiB
# ⠼ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 44.64 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 44.50 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 44.84 MiB/118.41 MiB
# triton     ------------------------------ 43.44 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 44.69 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 43.47 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 44.48 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 44.13 MiB/697.83 MiB
# ⠴ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 45.19 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 45.06 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 45.03 MiB/118.41 MiB
# triton     ------------------------------ 43.86 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 44.91 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 43.87 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 44.78 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 44.30 MiB/697.83 MiB
# ⠴ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 45.62 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 45.47 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 45.27 MiB/118.41 MiB
# triton     ------------------------------ 44.42 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 45.50 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 44.02 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 45.26 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 44.88 MiB/697.83 MiB
# ⠴ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 46.01 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 45.87 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 45.80 MiB/118.41 MiB
# triton     ------------------------------ 44.78 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 45.88 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 44.40 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 45.62 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 45.25 MiB/697.83 MiB
# ⠴ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 46.39 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 46.23 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 46.20 MiB/118.41 MiB
# triton     ------------------------------ 45.16 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 46.38 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 44.92 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 45.98 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 45.62 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 46.78 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 46.62 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 46.41 MiB/118.41 MiB
# triton     ------------------------------ 45.54 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 46.63 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 45.30 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 46.36 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 45.97 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 46.98 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 46.96 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 46.96 MiB/118.41 MiB
# triton     ------------------------------ 45.89 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 46.96 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 45.50 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 46.73 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 46.17 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 47.38 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 47.18 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 47.17 MiB/118.41 MiB
# triton     ------------------------------ 45.96 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 47.19 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 45.84 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 46.94 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 46.54 MiB/697.83 MiB
# ⠦ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 47.79 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 47.37 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 47.34 MiB/118.41 MiB
# triton     ------------------------------ 46.34 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 47.38 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 46.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 47.14 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 46.72 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 47.79 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 47.65 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 47.53 MiB/118.41 MiB
# triton     ------------------------------ 46.67 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 47.74 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 46.39 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 47.52 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 46.89 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 48.13 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 47.93 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 47.89 MiB/118.41 MiB
# triton     ------------------------------ 46.86 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 47.93 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 46.59 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 47.71 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 47.27 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 48.33 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 48.34 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 48.11 MiB/118.41 MiB
# triton     ------------------------------ 47.05 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 48.12 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 46.77 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 48.06 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 47.53 MiB/697.83 MiB
# ⠧ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 48.71 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 48.49 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 48.59 MiB/118.41 MiB
# triton     ------------------------------ 47.42 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 48.48 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 47.16 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 48.25 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 47.81 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 49.08 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 48.67 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 48.88 MiB/118.41 MiB
# triton     ------------------------------ 47.73 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 48.74 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 47.50 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 48.64 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 48.21 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 49.25 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 49.06 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 49.06 MiB/118.41 MiB
# triton     ------------------------------ 47.98 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 49.24 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 47.70 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 48.84 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 48.40 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 49.66 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 49.39 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 49.44 MiB/118.41 MiB
# triton     ------------------------------ 48.33 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 49.28 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 48.09 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 49.22 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 48.75 MiB/697.83 MiB
# ⠇ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 50.03 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 49.58 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 49.81 MiB/118.41 MiB
# triton     ------------------------------ 48.61 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 49.60 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 48.28 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 49.41 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 48.94 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 50.23 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 49.94 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 49.89 MiB/118.41 MiB
# triton     ------------------------------ 48.94 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 49.97 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 48.66 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 49.77 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 49.28 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 50.42 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 50.32 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 50.21 MiB/118.41 MiB
# triton     ------------------------------ 49.29 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 50.15 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 48.91 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 49.95 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 49.67 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 50.83 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 50.50 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 50.56 MiB/118.41 MiB
# triton     ------------------------------ 49.41 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 50.51 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 49.23 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 50.34 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 49.87 MiB/697.83 MiB
# ⠋ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 51.22 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 50.85 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 50.90 MiB/118.41 MiB
# triton     ------------------------------ 49.89 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 50.89 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 49.59 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 50.70 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 50.09 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 51.78 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 51.22 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 51.30 MiB/118.41 MiB
# triton     ------------------------------ 50.29 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 51.24 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 49.95 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 51.11 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 50.64 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 52.12 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 51.78 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 51.64 MiB/118.41 MiB
# triton     ------------------------------ 50.67 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 51.63 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 50.37 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 51.47 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 51.00 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 52.35 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 51.81 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 52.03 MiB/118.41 MiB
# triton     ------------------------------ 51.06 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 51.99 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 50.70 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 51.84 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 51.37 MiB/697.83 MiB
# ⠙ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 52.52 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 52.37 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 52.46 MiB/118.41 MiB
# triton     ------------------------------ 51.24 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 52.39 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 51.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 52.25 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 51.72 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 53.04 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 52.75 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 52.83 MiB/118.41 MiB
# triton     ------------------------------ 51.84 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 52.76 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 51.37 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 52.62 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 52.12 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 53.42 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 53.22 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 53.19 MiB/118.41 MiB
# triton     ------------------------------ 52.21 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 53.15 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 51.76 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 53.17 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 52.51 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 53.85 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 53.48 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 53.73 MiB/118.41 MiB
# triton     ------------------------------ 52.62 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 53.49 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 52.15 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 53.36 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 52.86 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-curand-cu12 ------------------------------ 53.85 MiB/53.85 MiB
# nvidia-cufft-cu12 ------------------------------ 53.87 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 53.98 MiB/118.41 MiB
# triton     ------------------------------ 53.03 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 53.93 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 52.53 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 53.77 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 53.12 MiB/697.83 MiB
# ⠹ Preparing packages... (4/13)
# nvidia-cufft-cu12 ------------------------------ 53.87 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 53.98 MiB/118.41 MiB
# triton     ------------------------------ 53.03 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 53.93 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 52.53 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 53.77 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 53.25 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-cufft-cu12 ------------------------------ 54.25 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 54.37 MiB/118.41 MiB
# triton     ------------------------------ 53.49 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 54.42 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 53.00 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 54.20 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 53.66 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-cufft-cu12 ------------------------------ 54.73 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 54.79 MiB/118.41 MiB
# triton     ------------------------------ 53.93 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 54.81 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 53.39 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 54.80 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 54.12 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-cufft-cu12 ------------------------------ 55.20 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 55.22 MiB/118.41 MiB
# triton     ------------------------------ 54.35 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 55.26 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 53.81 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 55.21 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 54.53 MiB/697.83 MiB
# ⠸ Preparing packages... (4/13)
# nvidia-cufft-cu12 ------------------------------ 55.67 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 55.68 MiB/118.41 MiB
# triton     ------------------------------ 54.74 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 55.72 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 54.20 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 55.53 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 54.91 MiB/697.83 MiB
# ⠼ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 55.88 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 56.12 MiB/118.41 MiB
# triton     ------------------------------ 55.19 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 56.14 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 54.41 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 55.94 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 55.23 MiB/697.83 MiB
# ⠼ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 56.28 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 56.32 MiB/118.41 MiB
# triton     ------------------------------ 55.52 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 56.36 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 54.85 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 56.12 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 55.61 MiB/697.83 MiB
# ⠼ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 56.73 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 56.69 MiB/118.41 MiB
# triton     ------------------------------ 55.77 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 56.81 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 55.29 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 56.62 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 56.03 MiB/697.83 MiB
# ⠼ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 56.94 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 56.92 MiB/118.41 MiB
# triton     ------------------------------ 55.96 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 57.21 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 55.47 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 57.03 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 56.28 MiB/697.83 MiB
# ⠴ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 57.41 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 57.31 MiB/118.41 MiB
# triton     ------------------------------ 56.38 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 57.40 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 55.91 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 57.30 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 56.70 MiB/697.83 MiB
# ⠴ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 57.84 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 57.70 MiB/118.41 MiB
# triton     ------------------------------ 56.66 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 57.62 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 56.12 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 57.73 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 57.16 MiB/697.83 MiB
# ⠴ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 58.06 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 57.94 MiB/118.41 MiB
# triton     ------------------------------ 57.00 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 58.08 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 56.53 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 57.95 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 57.45 MiB/697.83 MiB
# ⠴ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 58.27 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 58.38 MiB/118.41 MiB
# triton     ------------------------------ 57.41 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 58.49 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 56.83 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 58.12 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 57.77 MiB/697.83 MiB
# ⠦ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 58.95 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 58.60 MiB/118.41 MiB
# triton     ------------------------------ 57.70 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 58.95 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 57.39 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 58.53 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 57.99 MiB/697.83 MiB
# ⠦ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 59.16 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 59.00 MiB/118.41 MiB
# triton     ------------------------------ 58.38 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 59.18 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 57.74 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 58.94 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 58.44 MiB/697.83 MiB
# ⠦ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 59.38 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 59.42 MiB/118.41 MiB
# triton     ------------------------------ 58.64 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 59.39 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 58.06 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 59.12 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 58.86 MiB/697.83 MiB
# ⠦ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 59.81 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 59.65 MiB/118.41 MiB
# triton     ------------------------------ 58.84 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 59.78 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 58.25 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 59.55 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.08 MiB/697.83 MiB
# ⠧ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 60.03 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 59.89 MiB/118.41 MiB
# triton     ------------------------------ 59.05 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 59.78 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 58.25 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 59.69 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.28 MiB/697.83 MiB
# ⠧ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 60.23 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 59.89 MiB/118.41 MiB
# triton     ------------------------------ 59.22 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 60.20 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 58.48 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 60.00 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.50 MiB/697.83 MiB
# ⠧ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 60.48 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 60.30 MiB/118.41 MiB
# triton     ------------------------------ 59.44 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 60.41 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 58.89 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 60.00 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.50 MiB/697.83 MiB
# ⠧ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 60.48 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 60.30 MiB/118.41 MiB
# triton     ------------------------------ 59.69 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 60.59 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 59.10 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 60.21 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.74 MiB/697.83 MiB
# ⠇ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 60.91 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 60.48 MiB/118.41 MiB
# triton     ------------------------------ 59.69 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 60.82 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 59.10 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 60.62 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 59.97 MiB/697.83 MiB
# ⠇ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 61.12 MiB/116.00 MiB
# nvidia-cusolver-cu12 ------------------------------ 60.72 MiB/118.41 MiB
# triton     ------------------------------ 59.89 MiB/160.27 MiB
# nvidia-nccl-cu12 ------------------------------ 61.03 MiB/168.08 MiB
# nvidia-cusparse-cu12 ------------------------------ 59.37 MiB/186.88 MiB
# nvidia-cublas-cu12 ------------------------------ 60.84 MiB/391.57 MiB
# nvidia-cudnn-cu12 ------------------------------ 60.41 MiB/697.83 MiB
# ⠇ Preparing packages... (5/13)
# nvidia-cufft-cu12 ------------------------------ 61.34 MiB/116.00 MiB
# ...
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 661.75 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 661.80 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 663.29 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 663.29 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 664.03 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 665.29 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 665.29 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 665.39 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 666.03 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 667.20 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 667.28 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 667.28 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 667.95 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 669.22 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 669.48 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 669.89 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 671.29 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 671.29 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 671.29 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 672.28 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 673.00 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 673.29 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 673.29 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 673.29 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 673.48 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 674.83 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 675.47 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 677.23 MiB/697.83 MiB
# ⠧ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 677.44 MiB/697.83 MiB
# ⠧ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 678.11 MiB/697.83 MiB
# ⠧ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 678.11 MiB/697.83 MiB
# ⠧ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 678.26 MiB/697.83 MiB
# ⠇ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 678.32 MiB/697.83 MiB
# ⠇ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 680.02 MiB/697.83 MiB
# ⠇ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 680.09 MiB/697.83 MiB
# ⠇ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 680.09 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 680.38 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 681.36 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 682.08 MiB/697.83 MiB
# ⠋ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 682.45 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 682.67 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 684.27 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 684.44 MiB/697.83 MiB
# ⠙ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 685.29 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 686.91 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 687.64 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 688.11 MiB/697.83 MiB
# ⠹ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 688.27 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 688.97 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 690.08 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 690.58 MiB/697.83 MiB
# ⠸ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 691.59 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 692.11 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 692.11 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 692.95 MiB/697.83 MiB
# ⠼ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 693.69 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 694.73 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 694.95 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 695.95 MiB/697.83 MiB
# ⠴ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 696.11 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 696.36 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 697.47 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# nvidia-cudnn-cu12 ------------------------------ 697.83 MiB/697.83 MiB
# ⠦ Preparing packages... (11/13)
# ⠦ Preparing packages... (11/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠇ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠋ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠙ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠹ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠸ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠼ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠴ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠦ Preparing packages... (12/13)
# ⠧ Preparing packages... (12/13)
# Prepared 13 packages in 1m 06s
# Uninstalled 9 packages in 43ms
# Installed 13 packages in 457ms
#  - nvidia-cublas-cu12==12.6.3.3
#  + nvidia-cublas-cu12==12.1.3.1
#  - nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-cupti-cu12==12.1.105
#  + nvidia-cuda-nvrtc-cu12==12.1.105
#  - nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.1.105
#  - nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cudnn-cu12==8.9.2.26
#  - nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufft-cu12==11.0.2.54
#  - nvidia-curand-cu12==10.3.7.77
#  + nvidia-curand-cu12==10.3.2.106
#  - nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusolver-cu12==11.4.5.107
#  - nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparse-cu12==12.1.0.106
#  - nvidia-nccl-cu12==2.23.4
#  + nvidia-nccl-cu12==2.20.5
#  + nvidia-nvtx-cu12==12.1.105
#  + torch==2.3.0
#  + triton==2.3.0
# Using Python 3.10.12 environment at /usr
# Resolved 4 packages in 1.14s
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# torch-sparse ------------------------------     0 B/1.16 MiB
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# Prepared 2 packages in 62ms
# Installed 2 packages in 2ms
#  + pyg-lib==0.4.0+pt23cpu
#  + torch-sparse==0.6.18+pt23cpu

# %%
import torch
help(torch.version)
# Out:
# Help on module torch.version in torch:
#
# NAME
#     torch.version
#
# DATA
#     __all__ = ['__version__', 'debug', 'cuda', 'git_version', 'hip']
#     __annotations__ = {'cuda': typing.Optional[str], 'hip': typing.Optiona...
#     cuda = '12.1'
#     debug = False
#     git_version = '97ff6cfd9c86c5c09d7ce775ab64ec5c99230f5d'
#     hip = None
#
# VERSION
#     2.3.0+cu121
#
# FILE
#     /usr/local/lib/python3.10/dist-packages/torch/version.py

# %%
# !uv pip install pytorch_frame[full]==0.2.2 --system
# !uv pip install relbench[full]==1.0.0 --system
# Out:
# Using Python 3.10.12 environment at /usr
# Resolved 75 packages in 1.18s
# ⠙ Preparing packages... (0/12)
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------     0 B/189.60 KiB
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------     0 B/189.60 KiB
# optuna     ------------------------------     0 B/354.25 KiB
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------     0 B/354.25 KiB
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------     0 B/354.25 KiB
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# ⠙ Preparing packages... (0/12)
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------     0 B/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------     0 B/113.53 KiB
# multiprocess ------------------------------ 14.88 KiB/131.66 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------     0 B/76.72 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------ 14.88 KiB/131.66 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# colorlog   ------------------------------     0 B/11.16 KiB
# mako       ------------------------------ 14.89 KiB/76.72 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------ 14.88 KiB/131.66 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 14.88 KiB/189.60 KiB
# optuna     ------------------------------ 14.88 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------ 14.89 KiB/76.72 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------ 14.88 KiB/131.66 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 30.88 KiB/189.60 KiB
# optuna     ------------------------------ 22.35 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------ 14.89 KiB/76.72 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------ 14.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 8.74 KiB/137.45 KiB
# fsspec     ------------------------------ 14.88 KiB/175.05 KiB
# xxhash     ------------------------------ 46.88 KiB/189.60 KiB
# alembic    ------------------------------ 14.89 KiB/228.01 KiB
# optuna     ------------------------------ 38.35 KiB/354.25 KiB
# datasets   ------------------------------ 14.92 KiB/469.29 KiB
# catboost   ------------------------------ 46.91 KiB/94.17 MiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 56.74 KiB/137.45 KiB
# fsspec     ------------------------------ 110.78 KiB/175.05 KiB
# xxhash     ------------------------------ 189.60 KiB/189.60 KiB
# alembic    ------------------------------ 123.42 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 132.26 KiB/469.29 KiB
# catboost   ------------------------------ 313.44 KiB/94.17 MiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 56.74 KiB/137.45 KiB
# fsspec     ------------------------------ 110.78 KiB/175.05 KiB
# xxhash     ------------------------------ 189.60 KiB/189.60 KiB
# alembic    ------------------------------ 155.52 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 132.26 KiB/469.29 KiB
# catboost   ------------------------------ 1.98 MiB/94.17 MiB
# ⠙ Preparing packages... (0/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 56.74 KiB/137.45 KiB
# fsspec     ------------------------------ 126.78 KiB/175.05 KiB
# xxhash     ------------------------------ 189.60 KiB/189.60 KiB
# alembic    ------------------------------ 155.52 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 184.29 KiB/469.29 KiB
# catboost   ------------------------------ 3.91 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 72.74 KiB/137.45 KiB
# fsspec     ------------------------------ 126.78 KiB/175.05 KiB
# alembic    ------------------------------ 175.98 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 184.29 KiB/469.29 KiB
# catboost   ------------------------------ 3.97 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 72.74 KiB/137.45 KiB
# fsspec     ------------------------------ 142.78 KiB/175.05 KiB
# alembic    ------------------------------ 203.52 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 268.97 KiB/469.29 KiB
# catboost   ------------------------------ 4.45 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# mako       ------------------------------ 76.72 KiB/76.72 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 72.74 KiB/137.45 KiB
# fsspec     ------------------------------ 142.78 KiB/175.05 KiB
# alembic    ------------------------------ 203.52 KiB/228.01 KiB
# optuna     ------------------------------ 92.84 KiB/354.25 KiB
# datasets   ------------------------------ 268.97 KiB/469.29 KiB
# catboost   ------------------------------ 5.83 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------ 126.88 KiB/131.66 KiB
# pytorch-frame ------------------------------ 88.74 KiB/137.45 KiB
# fsspec     ------------------------------ 158.88 KiB/175.05 KiB
# alembic    ------------------------------ 219.52 KiB/228.01 KiB
# optuna     ------------------------------ 108.84 KiB/354.25 KiB
# datasets   ------------------------------ 268.97 KiB/469.29 KiB
# catboost   ------------------------------ 6.00 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# pytorch-frame ------------------------------ 88.74 KiB/137.45 KiB
# fsspec     ------------------------------ 158.88 KiB/175.05 KiB
# alembic    ------------------------------ 219.52 KiB/228.01 KiB
# optuna     ------------------------------ 108.84 KiB/354.25 KiB
# datasets   ------------------------------ 268.97 KiB/469.29 KiB
# catboost   ------------------------------ 6.00 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# pytorch-frame ------------------------------ 88.74 KiB/137.45 KiB
# fsspec     ------------------------------ 174.88 KiB/175.05 KiB
# optuna     ------------------------------ 108.84 KiB/354.25 KiB
# datasets   ------------------------------ 284.97 KiB/469.29 KiB
# catboost   ------------------------------ 6.00 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# pytorch-frame ------------------------------ 88.74 KiB/137.45 KiB
# optuna     ------------------------------ 108.84 KiB/354.25 KiB
# datasets   ------------------------------ 284.97 KiB/469.29 KiB
# catboost   ------------------------------ 6.00 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# pytorch-frame ------------------------------ 88.74 KiB/137.45 KiB
# optuna     ------------------------------ 124.84 KiB/354.25 KiB
# datasets   ------------------------------ 284.97 KiB/469.29 KiB
# catboost   ------------------------------ 7.53 MiB/94.17 MiB
# ⠹ Preparing packages... (1/12)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# pytorch-frame ------------------------------ 104.74 KiB/137.45 KiB
# optuna     ------------------------------ 140.84 KiB/354.25 KiB
# datasets   ------------------------------ 300.97 KiB/469.29 KiB
# catboost   ------------------------------ 10.27 MiB/94.17 MiB
# ⠸ Preparing packages... (6/12)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# pytorch-frame ------------------------------ 104.74 KiB/137.45 KiB
# optuna     ------------------------------ 145.41 KiB/354.25 KiB
# datasets   ------------------------------ 300.97 KiB/469.29 KiB
# catboost   ------------------------------ 11.52 MiB/94.17 MiB
# ⠸ Preparing packages... (6/12)
# pytorch-frame ------------------------------ 104.74 KiB/137.45 KiB
# optuna     ------------------------------ 145.41 KiB/354.25 KiB
# datasets   ------------------------------ 313.80 KiB/469.29 KiB
# catboost   ------------------------------ 12.00 MiB/94.17 MiB
# ⠸ Preparing packages... (6/12)
# pytorch-frame ------------------------------ 104.74 KiB/137.45 KiB
# optuna     ------------------------------ 145.41 KiB/354.25 KiB
# datasets   ------------------------------ 313.80 KiB/469.29 KiB
# catboost   ------------------------------ 13.09 MiB/94.17 MiB
# ⠸ Preparing packages... (6/12)
# pytorch-frame ------------------------------ 120.74 KiB/137.45 KiB
# optuna     ------------------------------ 161.41 KiB/354.25 KiB
# datasets   ------------------------------ 332.97 KiB/469.29 KiB
# catboost   ------------------------------ 15.12 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# pytorch-frame ------------------------------ 120.74 KiB/137.45 KiB
# optuna     ------------------------------ 161.41 KiB/354.25 KiB
# datasets   ------------------------------ 332.97 KiB/469.29 KiB
# catboost   ------------------------------ 16.14 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# pytorch-frame ------------------------------ 120.74 KiB/137.45 KiB
# optuna     ------------------------------ 161.41 KiB/354.25 KiB
# datasets   ------------------------------ 332.97 KiB/469.29 KiB
# catboost   ------------------------------ 17.50 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# pytorch-frame ------------------------------ 120.74 KiB/137.45 KiB
# optuna     ------------------------------ 177.41 KiB/354.25 KiB
# datasets   ------------------------------ 348.97 KiB/469.29 KiB
# catboost   ------------------------------ 19.95 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# pytorch-frame ------------------------------ 137.45 KiB/137.45 KiB
# optuna     ------------------------------ 177.41 KiB/354.25 KiB
# datasets   ------------------------------ 364.97 KiB/469.29 KiB
# catboost   ------------------------------ 21.41 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# optuna     ------------------------------ 177.41 KiB/354.25 KiB
# datasets   ------------------------------ 364.97 KiB/469.29 KiB
# catboost   ------------------------------ 21.96 MiB/94.17 MiB
# ⠼ Preparing packages... (7/12)
# optuna     ------------------------------ 177.41 KiB/354.25 KiB
# datasets   ------------------------------ 364.97 KiB/469.29 KiB
# catboost   ------------------------------ 22.30 MiB/94.17 MiB
# ⠴ Preparing packages... (8/12)
# optuna     ------------------------------ 193.41 KiB/354.25 KiB
# datasets   ------------------------------ 380.97 KiB/469.29 KiB
# catboost   ------------------------------ 23.18 MiB/94.17 MiB
# ⠴ Preparing packages... (8/12)
# optuna     ------------------------------ 193.41 KiB/354.25 KiB
# datasets   ------------------------------ 380.97 KiB/469.29 KiB
# catboost   ------------------------------ 25.12 MiB/94.17 MiB
# ⠴ Preparing packages... (8/12)
# optuna     ------------------------------ 204.84 KiB/354.25 KiB
# datasets   ------------------------------ 380.97 KiB/469.29 KiB
# catboost   ------------------------------ 26.80 MiB/94.17 MiB
# ⠴ Preparing packages... (8/12)
# optuna     ------------------------------ 204.84 KiB/354.25 KiB
# datasets   ------------------------------ 380.97 KiB/469.29 KiB
# catboost   ------------------------------ 28.48 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# optuna     ------------------------------ 220.84 KiB/354.25 KiB
# datasets   ------------------------------ 444.97 KiB/469.29 KiB
# catboost   ------------------------------ 30.00 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# optuna     ------------------------------ 220.84 KiB/354.25 KiB
# catboost   ------------------------------ 30.18 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# catboost   ------------------------------ 30.18 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# catboost   ------------------------------ 30.51 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# catboost   ------------------------------ 33.23 MiB/94.17 MiB
# ⠦ Preparing packages... (8/12)
# catboost   ------------------------------ 34.45 MiB/94.17 MiB
# ⠧ Preparing packages... (10/12)
# catboost   ------------------------------ 36.94 MiB/94.17 MiB
# ⠧ Preparing packages... (10/12)
# catboost   ------------------------------ 38.62 MiB/94.17 MiB
# ⠧ Preparing packages... (10/12)
# catboost   ------------------------------ 40.34 MiB/94.17 MiB
# ⠧ Preparing packages... (10/12)
# catboost   ------------------------------ 41.84 MiB/94.17 MiB
# ⠇ Preparing packages... (10/12)
# catboost   ------------------------------ 43.80 MiB/94.17 MiB
# ⠇ Preparing packages... (10/12)
# catboost   ------------------------------ 46.17 MiB/94.17 MiB
# ⠇ Preparing packages... (10/12)
# catboost   ------------------------------ 49.45 MiB/94.17 MiB
# ⠇ Preparing packages... (10/12)
# catboost   ------------------------------ 52.88 MiB/94.17 MiB
# ⠋ Preparing packages... (10/12)
# catboost   ------------------------------ 55.14 MiB/94.17 MiB
# ⠋ Preparing packages... (10/12)
# catboost   ------------------------------ 56.77 MiB/94.17 MiB
# ⠋ Preparing packages... (10/12)
# catboost   ------------------------------ 57.84 MiB/94.17 MiB
# ⠋ Preparing packages... (10/12)
# catboost   ------------------------------ 58.88 MiB/94.17 MiB
# ⠙ Preparing packages... (10/12)
# catboost   ------------------------------ 59.83 MiB/94.17 MiB
# ⠙ Preparing packages... (10/12)
# catboost   ------------------------------ 60.81 MiB/94.17 MiB
# ⠙ Preparing packages... (10/12)
# catboost   ------------------------------ 62.81 MiB/94.17 MiB
# ⠙ Preparing packages... (10/12)
# catboost   ------------------------------ 64.56 MiB/94.17 MiB
# ⠹ Preparing packages... (10/12)
# catboost   ------------------------------ 66.58 MiB/94.17 MiB
# ⠹ Preparing packages... (10/12)
# catboost   ------------------------------ 67.73 MiB/94.17 MiB
# ⠹ Preparing packages... (10/12)
# catboost   ------------------------------ 70.14 MiB/94.17 MiB
# ⠹ Preparing packages... (10/12)
# catboost   ------------------------------ 72.39 MiB/94.17 MiB
# ⠸ Preparing packages... (10/12)
# catboost   ------------------------------ 74.03 MiB/94.17 MiB
# ⠸ Preparing packages... (10/12)
# catboost   ------------------------------ 76.95 MiB/94.17 MiB
# ⠸ Preparing packages... (10/12)
# catboost   ------------------------------ 78.84 MiB/94.17 MiB
# ⠸ Preparing packages... (10/12)
# catboost   ------------------------------ 82.03 MiB/94.17 MiB
# ⠼ Preparing packages... (10/12)
# catboost   ------------------------------ 84.39 MiB/94.17 MiB
# ⠼ Preparing packages... (10/12)
# catboost   ------------------------------ 86.37 MiB/94.17 MiB
# ⠼ Preparing packages... (10/12)
# catboost   ------------------------------ 88.37 MiB/94.17 MiB
# ⠼ Preparing packages... (10/12)
# catboost   ------------------------------ 89.64 MiB/94.17 MiB
# ⠴ Preparing packages... (10/12)
# catboost   ------------------------------ 90.71 MiB/94.17 MiB
# ⠴ Preparing packages... (10/12)
# catboost   ------------------------------ 91.12 MiB/94.17 MiB
# ⠴ Preparing packages... (10/12)
# catboost   ------------------------------ 92.62 MiB/94.17 MiB
# ⠴ Preparing packages... (10/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠋ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠴ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠙ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠼ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠦ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠧ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# ⠇ Preparing packages... (11/12)
# Prepared 12 packages in 12.32s
# Uninstalled 2 packages in 10ms
# Installed 12 packages in 31ms
#  + alembic==1.14.0
#  + catboost==1.2.7
#  + colorlog==6.9.0
#  + datasets==3.1.0
#  + dill==0.3.8
#  - fsspec==2024.10.0
#  + fsspec==2024.9.0
#  + mako==1.3.6
#  + multiprocess==0.70.16
#  + optuna==4.0.0
#  + pytorch-frame==0.2.2
#  - xgboost==2.1.2
#  + xgboost==1.7.6
#  + xxhash==3.5.0
# Using Python 3.10.12 environment at /usr
# Resolved 58 packages in 1.24s
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠹ Preparing packages... (1/3)
# ⠹ Preparing packages... (1/3)
# ⠹ Preparing packages... (1/3)
# ⠹ Preparing packages... (1/3)
# Prepared 3 packages in 370ms
# Uninstalled 1 package in 4ms
# Installed 3 packages in 22ms
#  - pytorch-frame==0.2.2
#  + pytorch-frame==0.2.3
#  + relbench==1.0.0
#  + torch-geometric==2.6.1

# %%
import relbench

relbench.__version__
# Out:
# '1.0.0'

# %%
# !uv pip install sentence-transformers==3.0.1 --system
# Out:
# Using Python 3.10.12 environment at /usr
# Resolved 42 packages in 438ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# Prepared 1 package in 58ms
# Uninstalled 1 package in 9ms
# Installed 1 package in 3ms
#  - sentence-transformers==3.2.1
#  + sentence-transformers==3.0.1

# %%
# !uv pip install git+https://github.com/pyg-team/pytorch_geometric.git --system
# Out:
# Using Python 3.10.12 environment at /usr
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
# Updating https://github.com/pyg-team/pytorch_geometric.git (HEAD)
#  Updated https://github.com/pyg-team/pytorch_geometric.git (f5c82934)
# Resolved 23 packages in 4.62s
# Building torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
# Building torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
# Building torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
# Building torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
# Building torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
#    Built torch-geometric @ git+https://github.com/pyg-team/pytorch_geometric.git@f5c
# Prepared 1 package in 851ms
# Uninstalled 1 package in 10ms
# Installed 1 package in 15ms
#  - torch-geometric==2.6.1
#  + torch-geometric==2.7.0 (from git+https://github.com/pyg-team/pytorch_geometric.git@f5c829344517c823c24abb08ce2fc7cf00ff29f7)

# %%
import torch_geometric
print(torch_geometric.typing.WITH_PYG_LIB)
# Out:
# True

# %% [markdown]
# **Load Data**

# %%
import numpy as np

from torch.nn import BCEWithLogitsLoss, L1Loss
from relbench.datasets import get_dataset
from relbench.tasks import get_task

dataset = get_dataset("rel-f1", download=True)
task = get_task("rel-f1", "driver-position", download=True)

train_table = task.get_table("train")
val_table = task.get_table("val")
test_table = task.get_table("test")

out_channels = 1
loss_fn = L1Loss()
tune_metric = "mae"
higher_is_better = False
# Out:
# Downloading file 'rel-f1/db.zip' from 'https://relbench.stanford.edu/download/rel-f1/db.zip' to '/root/.cache/relbench'.
# 100%|████████████████████████████████████████| 704k/704k [00:00<00:00, 493MB/s]
# Unzipping contents of '/root/.cache/relbench/rel-f1/db.zip' to '/root/.cache/relbench/rel-f1/.'
# Downloading file 'rel-f1/tasks/driver-position.zip' from 'https://relbench.stanford.edu/download/rel-f1/tasks/driver-position.zip' to '/root/.cache/relbench'.
# 100%|█████████████████████████████████████| 36.5k/36.5k [00:00<00:00, 16.1MB/s]
# Unzipping contents of '/root/.cache/relbench/rel-f1/tasks/driver-position.zip' to '/root/.cache/relbench/rel-f1/tasks/.'

# %%
train_table
# Out:
# Table(df=
#            date  driverId  position
# 0    2004-07-05        10     10.75
# 1    2004-07-05        47     12.00
# 2    2004-03-07         7     15.00
# 3    2004-01-07        10      9.00
# 4    2003-09-09        52     13.00
# ...         ...       ...       ...
# 7448 1995-08-22        96     15.75
# 7449 1975-06-08       228      8.00
# 7450 1965-05-31       418     16.00
# 7451 1961-08-20       467     37.00
# 7452 1954-05-29       677     30.00
#
# [7453 rows x 3 columns],
#   fkey_col_to_pkey_table={'driverId': 'drivers'},
#   pkey_col=None,
#   time_col=date)

# %%
test_table
# Out:
# Table(df=
#           date  driverId
# 0   2016-05-29       835
# 1   2016-03-30         3
# 2   2016-03-30       807
# 3   2016-03-30       831
# 4   2016-01-30       830
# ..         ...       ...
# 755 2010-10-28        66
# 756 2010-10-28        19
# 757 2010-10-28         8
# 758 2010-08-29         0
# 759 2010-08-29        16
#
# [760 rows x 2 columns],
#   fkey_col_to_pkey_table={'driverId': 'drivers'},
#   pkey_col=None,
#   time_col=date)

# %%
val_table
# Out:
# Table(df=
#           date  driverId   position
# 0   2009-08-08         7   4.200000
# 1   2009-06-09        11  12.333333
# 2   2009-06-09         0  11.666667
# 3   2009-04-10         5  15.600000
# 4   2009-04-10        17   1.400000
# ..         ...       ...        ...
# 494 2005-06-30        16  13.800000
# 495 2005-03-02        32  12.750000
# 496 2008-10-12        14  11.000000
# 497 2007-06-20        28  22.000000
# 498 2006-02-25        14  16.500000
#
# [499 rows x 3 columns],
#   fkey_col_to_pkey_table={'driverId': 'drivers'},
#   pkey_col=None,
#   time_col=date)

# %%
import torch

# Some book keeping
from torch_geometric.seed import seed_everything

seed_everything(42)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)  # check that it's cuda if you want it to run in reasonable time!
root_dir = "./data"
# Out:
# cpu

# %%
from relbench.modeling.utils import get_stype_proposal

db = dataset.get_db()
col_to_stype_dict = get_stype_proposal(db)
col_to_stype_dict
# Out:
# Loading Database object from /root/.cache/relbench/rel-f1/db...
# Done in 0.05 seconds.
# {'races': {'raceId': <stype.numerical: 'numerical'>,
#   'year': <stype.categorical: 'categorical'>,
#   'round': <stype.numerical: 'numerical'>,
#   'circuitId': <stype.numerical: 'numerical'>,
#   'name': <stype.text_embedded: 'text_embedded'>,
#   'date': <stype.timestamp: 'timestamp'>,
#   'time': <stype.timestamp: 'timestamp'>},
#  'constructor_standings': {'constructorStandingsId': <stype.numerical: 'numerical'>,
#   'raceId': <stype.numerical: 'numerical'>,
#   'constructorId': <stype.numerical: 'numerical'>,
#   'points': <stype.numerical: 'numerical'>,
#   'position': <stype.numerical: 'numerical'>,
#   'wins': <stype.numerical: 'numerical'>,
#   'date': <stype.timestamp: 'timestamp'>},
#  'results': {'resultId': <stype.numerical: 'numerical'>,
#   'raceId': <stype.numerical: 'numerical'>,
#   'driverId': <stype.numerical: 'numerical'>,
#   'constructorId': <stype.numerical: 'numerical'>,
#   'number': <stype.numerical: 'numerical'>,
#   'grid': <stype.numerical: 'numerical'>,
#   'position': <stype.numerical: 'numerical'>,
#   'positionOrder': <stype.numerical: 'numerical'>,
#   'points': <stype.numerical: 'numerical'>,
#   'laps': <stype.numerical: 'numerical'>,
#   'milliseconds': <stype.numerical: 'numerical'>,
#   'fastestLap': <stype.numerical: 'numerical'>,
#   'rank': <stype.numerical: 'numerical'>,
#   'statusId': <stype.numerical: 'numerical'>,
#   'date': <stype.timestamp: 'timestamp'>},
#  'drivers': {'driverId': <stype.numerical: 'numerical'>,
#   'driverRef': <stype.text_embedded: 'text_embedded'>,
#   'code': <stype.text_embedded: 'text_embedded'>,
#   'forename': <stype.text_embedded: 'text_embedded'>,
#   'surname': <stype.text_embedded: 'text_embedded'>,
#   'dob': <stype.timestamp: 'timestamp'>,
#   'nationality': <stype.text_embedded: 'text_embedded'>},
#  'qualifying': {'qualifyId': <stype.numerical: 'numerical'>,
#   'raceId': <stype.numerical: 'numerical'>,
#   'driverId': <stype.numerical: 'numerical'>,
#   'constructorId': <stype.numerical: 'numerical'>,
#   'number': <stype.numerical: 'numerical'>,
#   'position': <stype.numerical: 'numerical'>,
#   'date': <stype.timestamp: 'timestamp'>},
#  'constructor_results': {'constructorResultsId': <stype.numerical: 'numerical'>,
#   'raceId': <stype.numerical: 'numerical'>,
#   'constructorId': <stype.numerical: 'numerical'>,
#   'points': <stype.numerical: 'numerical'>,
#   'date': <stype.timestamp: 'timestamp'>},
#  'circuits': {'circuitId': <stype.numerical: 'numerical'>,
#   'circuitRef': <stype.text_embedded: 'text_embedded'>,
#   'name': <stype.text_embedded: 'text_embedded'>,
#   'location': <stype.text_embedded: 'text_embedded'>,
#   'country': <stype.text_embedded: 'text_embedded'>,
#   'lat': <stype.numerical: 'numerical'>,
#   'lng': <stype.numerical: 'numerical'>,
#   'alt': <stype.numerical: 'numerical'>},
#  'constructors': {'constructorId': <stype.numerical: 'numerical'>,
#   'constructorRef': <stype.text_embedded: 'text_embedded'>,
#   'name': <stype.text_embedded: 'text_embedded'>,
#   'nationality': <stype.text_embedded: 'text_embedded'>},
#  'standings': {'driverStandingsId': <stype.numerical: 'numerical'>,
#   'raceId': <stype.numerical: 'numerical'>,
#   'driverId': <stype.numerical: 'numerical'>,
#   'points': <stype.numerical: 'numerical'>,
#   'position': <stype.numerical: 'numerical'>,
#   'wins': <stype.numerical: 'numerical'>,
#   'date': <stype.timestamp: 'timestamp'>}}

# %% [markdown]
# **Setup Data Loaders and Embedders**

# %%
from typing import List, Optional
from sentence_transformers import SentenceTransformer
from torch import Tensor


class GloveTextEmbedding:
    def __init__(self, device: Optional[torch.device
                                       ] = None):
        self.model = SentenceTransformer(
            "sentence-transformers/average_word_embeddings_glove.6B.300d",
            device=device,
        )

    def __call__(self, sentences: List[str]) -> Tensor:
        return torch.from_numpy(self.model.encode(sentences))

# %%
import os
from torch_frame.config.text_embedder import TextEmbedderConfig
from relbench.modeling.graph import make_pkey_fkey_graph

text_embedder_cfg = TextEmbedderConfig(
    text_embedder=GloveTextEmbedding(device=device), batch_size=256
)

data, col_stats_dict = make_pkey_fkey_graph(
    db,
    col_to_stype_dict=col_to_stype_dict,  # speficied column types
    text_embedder_cfg=text_embedder_cfg,  # our chosen text encoder
    cache_dir=os.path.join(
        root_dir, f"rel-f1_materialized_cache"
    ),  # store materialized graph for convenience
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/248 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/480M [00:00<?, ?B/s]
# (…)WordEmbeddings/wordembedding_config.json:   0%|          | 0.00/164 [00:00<?, ?B/s]
# (…)beddings/whitespacetokenizer_config.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch_frame/data/stats.py:177: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ser = pd.to_datetime(ser, format=time_format)
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 141.08it/s]
# /usr/local/lib/python3.10/dist-packages/torch_frame/data/mapper.py:290: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ser = pd.to_datetime(ser, format=self.format, errors='coerce')
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 111.56it/s]
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 117.62it/s]
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 179.62it/s]
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 173.62it/s]
# Embedding raw data in mini-batch: 100%|██████████| 4/4 [00:00<00:00, 149.56it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 201.19it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 240.21it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 242.67it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 221.94it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 126.64it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 116.12it/s]
# Embedding raw data in mini-batch: 100%|██████████| 1/1 [00:00<00:00, 57.89it/s]

# %%
data
# Out:
# HeteroData(
#   races={
#     tf=TensorFrame([820, 5]),
#     time=[820],
#   },
#   constructor_standings={
#     tf=TensorFrame([10170, 4]),
#     time=[10170],
#   },
#   results={
#     tf=TensorFrame([20323, 11]),
#     time=[20323],
#   },
#   drivers={ tf=TensorFrame([857, 6]) },
#   qualifying={
#     tf=TensorFrame([4082, 3]),
#     time=[4082],
#   },
#   constructor_results={
#     tf=TensorFrame([9408, 2]),
#     time=[9408],
#   },
#   circuits={ tf=TensorFrame([77, 7]) },
#   constructors={ tf=TensorFrame([211, 3]) },
#   standings={
#     tf=TensorFrame([28115, 4]),
#     time=[28115],
#   },
#   (races, f2p_circuitId, circuits)={ edge_index=[2, 820] },
#   (circuits, rev_f2p_circuitId, races)={ edge_index=[2, 820] },
#   (constructor_standings, f2p_raceId, races)={ edge_index=[2, 10170] },
#   (races, rev_f2p_raceId, constructor_standings)={ edge_index=[2, 10170] },
#   (constructor_standings, f2p_constructorId, constructors)={ edge_index=[2, 10170] },
#   (constructors, rev_f2p_constructorId, constructor_standings)={ edge_index=[2, 10170] },
#   (results, f2p_raceId, races)={ edge_index=[2, 20323] },
#   (races, rev_f2p_raceId, results)={ edge_index=[2, 20323] },
#   (results, f2p_driverId, drivers)={ edge_index=[2, 20323] },
#   (drivers, rev_f2p_driverId, results)={ edge_index=[2, 20323] },
#   (results, f2p_constructorId, constructors)={ edge_index=[2, 20323] },
#   (constructors, rev_f2p_constructorId, results)={ edge_index=[2, 20323] },
#   (qualifying, f2p_raceId, races)={ edge_index=[2, 4082] },
#   (races, rev_f2p_raceId, qualifying)={ edge_index=[2, 4082] },
#   (qualifying, f2p_driverId, drivers)={ edge_index=[2, 4082] },
#   (drivers, rev_f2p_driverId, qualifying)={ edge_index=[2, 4082] },
#   (qualifying, f2p_constructorId, constructors)={ edge_index=[2, 4082] },
#   (constructors, rev_f2p_constructorId, qualifying)={ edge_index=[2, 4082] },
#   (constructor_results, f2p_raceId, races)={ edge_index=[2, 9408] },
#   (races, rev_f2p_raceId, constructor_results)={ edge_index=[2, 9408] },
#   (constructor_results, f2p_constructorId, constructors)={ edge_index=[2, 9408] },
#   (constructors, rev_f2p_constructorId, constructor_results)={ edge_index=[2, 9408] },
#   (standings, f2p_raceId, races)={ edge_index=[2, 28115] },
#   (races, rev_f2p_raceId, standings)={ edge_index=[2, 28115] },
#   (standings, f2p_driverId, drivers)={ edge_index=[2, 28115] },
#   (drivers, rev_f2p_driverId, standings)={ edge_index=[2, 28115] }
# )

# %%
data["races"].tf
# Out:
# TensorFrame(
#   num_cols=5,
#   num_rows=820,
#   categorical (1): ['year'],
#   numerical (1): ['round'],
#   timestamp (2): ['date', 'time'],
#   embedding (1): ['name'],
#   has_target=False,
#   device='cpu',
# )

# %%
list(data["races"].keys())
# Out:
# ['tf', 'time']

# %%
data["races"].tf[10]
# Out:
# TensorFrame(
#   num_cols=5,
#   num_rows=1,
#   categorical (1): ['year'],
#   numerical (1): ['round'],
#   timestamp (2): ['date', 'time'],
#   embedding (1): ['name'],
#   has_target=False,
#   device='cpu',
# )

# %%
data["races"].tf[10:20]
# Out:
# TensorFrame(
#   num_cols=5,
#   num_rows=10,
#   categorical (1): ['year'],
#   numerical (1): ['round'],
#   timestamp (2): ['date', 'time'],
#   embedding (1): ['name'],
#   has_target=False,
#   device='cpu',
# )

# %%
data[("races", "f2p_circuitId", "circuits")]
# Out:
# {'edge_index': tensor([[  0,   1,   2,  ..., 817, 818, 819],
#         [  8,   5,  18,  ...,  21,  17,  23]])}

# %%
from relbench.modeling.graph import get_node_train_table_input
from torch_geometric.loader import NeighborLoader

loader_dict = {}

for split, table in [
    ("train", train_table),
    ("val", val_table),
    ("test", test_table),
]:
    table_input = get_node_train_table_input(
        table=table,
        task=task,
    )
    entity_table = table_input.nodes[0]
    loader_dict[split] = NeighborLoader(
        data,
        num_neighbors=[
            128 for i in range(2)
        ],  # we sample subgraphs of depth 2, 128 neighbors per node.
        time_attr="time",
        input_nodes=table_input.nodes,
        input_time=table_input.time,
        transform=table_input.transform,
        batch_size=512,
        temporal_strategy="uniform",
        shuffle=split == "train",
        num_workers=0,
        persistent_workers=False,
    )

# %% [markdown]
# **Model Training**

# %%
from torch.nn import BCEWithLogitsLoss
import copy
from typing import Any, Dict, List

import torch
from torch import Tensor
from torch.nn import Embedding, ModuleDict
from torch_frame.data.stats import StatType
from torch_geometric.data import HeteroData
from torch_geometric.nn import MLP
from torch_geometric.typing import NodeType

from relbench.modeling.nn import HeteroEncoder, HeteroGraphSAGE, HeteroTemporalEncoder


class Model(torch.nn.Module):

    def __init__(
        self,
        data: HeteroData,
        col_stats_dict: Dict[str, Dict[str, Dict[StatType, Any]]],
        num_layers: int,
        channels: int,
        out_channels: int,
        aggr: str,
        norm: str,
        # List of node types to add shallow embeddings to input
        shallow_list: List[NodeType] = [],
        # ID awareness
        id_awareness: bool = False,
    ):
        super().__init__()

        self.encoder = HeteroEncoder(
            channels=channels,
            node_to_col_names_dict={
                node_type: data[node_type].tf.col_names_dict
                for node_type in data.node_types
            },
            node_to_col_stats=col_stats_dict,
        )
        self.temporal_encoder = HeteroTemporalEncoder(
            node_types=[
                node_type for node_type in data.node_types if "time" in data[node_type]
            ],
            channels=channels,
        )
        self.gnn = HeteroGraphSAGE(
            node_types=data.node_types,
            edge_types=data.edge_types,
            channels=channels,
            aggr=aggr,
            num_layers=num_layers,
        )
        self.head = MLP(
            channels,
            out_channels=out_channels,
            norm=norm,
            num_layers=1,
        )
        self.embedding_dict = ModuleDict(
            {
                node: Embedding(data.num_nodes_dict[node], channels)
                for node in shallow_list
            }
        )

        self.id_awareness_emb = None
        if id_awareness:
            self.id_awareness_emb = torch.nn.Embedding(1, channels)
        self.reset_parameters()

    def reset_parameters(self):
        self.encoder.reset_parameters()
        self.temporal_encoder.reset_parameters()
        self.gnn.reset_parameters()
        self.head.reset_parameters()
        for embedding in self.embedding_dict.values():
            torch.nn.init.normal_(embedding.weight, std=0.1)
        if self.id_awareness_emb is not None:
            self.id_awareness_emb.reset_parameters()

    def forward(
        self,
        batch: HeteroData,
        entity_table: NodeType,
    ) -> Tensor:
        seed_time = batch[entity_table].seed_time
        x_dict = self.encoder(batch.tf_dict)

        rel_time_dict = self.temporal_encoder(
            seed_time, batch.time_dict, batch.batch_dict
        )

        for node_type, rel_time in rel_time_dict.items():
            x_dict[node_type] = x_dict[node_type] + rel_time

        for node_type, embedding in self.embedding_dict.items():
            x_dict[node_type] = x_dict[node_type] + embedding(batch[node_type].n_id)

        x_dict = self.gnn(
            x_dict,
            batch.edge_index_dict,
            batch.num_sampled_nodes_dict,
            batch.num_sampled_edges_dict,
        )

        return self.head(x_dict[entity_table][: seed_time.size(0)])

    def forward_dst_readout(
        self,
        batch: HeteroData,
        entity_table: NodeType,
        dst_table: NodeType,
    ) -> Tensor:
        if self.id_awareness_emb is None:
            raise RuntimeError(
                "id_awareness must be set True to use forward_dst_readout"
            )
        seed_time = batch[entity_table].seed_time
        x_dict = self.encoder(batch.tf_dict)
        # Add ID-awareness to the root node
        x_dict[entity_table][: seed_time.size(0)] += self.id_awareness_emb.weight

        rel_time_dict = self.temporal_encoder(
            seed_time, batch.time_dict, batch.batch_dict
        )

        for node_type, rel_time in rel_time_dict.items():
            x_dict[node_type] = x_dict[node_type] + rel_time

        for node_type, embedding in self.embedding_dict.items():
            x_dict[node_type] = x_dict[node_type] + embedding(batch[node_type].n_id)

        x_dict = self.gnn(
            x_dict,
            batch.edge_index_dict,
        )

        return self.head(x_dict[dst_table])


model = Model(
    data=data,
    col_stats_dict=col_stats_dict,
    num_layers=2,
    channels=128,
    out_channels=1,
    aggr="sum",
    norm="batch_norm",
).to(device)


# if you try out different RelBench tasks you will need to change these
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
epochs = 10

# %%
def train() -> float:
    model.train()

    loss_accum = count_accum = 0
    for batch in tqdm(loader_dict["train"]):
        batch = batch.to(device)

        optimizer.zero_grad()
        pred = model(
            batch,
            task.entity_table,
        )
        pred = pred.view(-1) if pred.size(1) == 1 else pred

        loss = loss_fn(pred.float(), batch[entity_table].y.float())
        loss.backward()
        optimizer.step()

        loss_accum += loss.detach().item() * pred.size(0)
        count_accum += pred.size(0)

    return loss_accum / count_accum


@torch.no_grad()
def test(loader: NeighborLoader) -> np.ndarray:
    model.eval()

    pred_list = []
    for batch in loader:
        batch = batch.to(device)
        pred = model(
            batch,
            task.entity_table,
        )
        pred = pred.view(-1) if pred.size(1) == 1 else pred
        pred_list.append(pred.detach().cpu())
    return torch.cat(pred_list, dim=0).numpy()

# %%
import math
from tqdm import tqdm


state_dict = None
best_val_metric = -math.inf if higher_is_better else math.inf
for epoch in range(1, epochs + 1):
    train_loss = train()
    val_pred = test(loader_dict["val"])
    val_metrics = task.evaluate(val_pred, val_table)
    print(f"Epoch: {epoch:02d}, Train loss: {train_loss}, Val metrics: {val_metrics}")

    if (higher_is_better and val_metrics[tune_metric] > best_val_metric) or (
        not higher_is_better and val_metrics[tune_metric] < best_val_metric
    ):
        best_val_metric = val_metrics[tune_metric]
        state_dict = copy.deepcopy(model.state_dict())


model.load_state_dict(state_dict)
val_pred = test(loader_dict["val"])
val_metrics = task.evaluate(val_pred, val_table)
print(f"Best Val metrics: {val_metrics}")

test_pred = test(loader_dict["test"])
test_metrics = task.evaluate(test_pred)
print(f"Best test metrics: {test_metrics}")
# Out:
# 100%|██████████| 15/15 [01:34<00:00,  6.32s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 01, Train loss: 9.225977462329402, Val metrics: {'r2': -0.27516523036351126, 'mae': 4.404741515934906, 'rmse': 5.2352029313667465}
# 100%|██████████| 15/15 [01:31<00:00,  6.08s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 02, Train loss: 5.9143301336042, Val metrics: {'r2': -0.340243583810399, 'mae': 4.277408068293162, 'rmse': 5.36713053561704}
# 100%|██████████| 15/15 [01:30<00:00,  6.07s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 03, Train loss: 5.541605031363967, Val metrics: {'r2': 0.022295529699196792, 'mae': 3.7725451719784786, 'rmse': 4.5841000747188225}
# 100%|██████████| 15/15 [01:34<00:00,  6.31s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 04, Train loss: 5.401864896024711, Val metrics: {'r2': 0.0516118241076875, 'mae': 3.7364383018407015, 'rmse': 4.514850301224815}
# 100%|██████████| 15/15 [01:32<00:00,  6.18s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 05, Train loss: 5.380020895468761, Val metrics: {'r2': 0.07345255571644205, 'mae': 3.6759226305292065, 'rmse': 4.462560539761526}
# 100%|██████████| 15/15 [01:31<00:00,  6.10s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 06, Train loss: 5.299729084914184, Val metrics: {'r2': 0.1373656757341083, 'mae': 3.526783672618165, 'rmse': 4.305897198441114}
# 100%|██████████| 15/15 [01:35<00:00,  6.38s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 07, Train loss: 5.029066553055705, Val metrics: {'r2': 0.17630107904687853, 'mae': 3.436991537931209, 'rmse': 4.207600888608754}
# 100%|██████████| 15/15 [01:30<00:00,  6.00s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 08, Train loss: 4.895234280971014, Val metrics: {'r2': 0.24672414877039717, 'mae': 3.2581881723805277, 'rmse': 4.023715926928288}
# 100%|██████████| 15/15 [01:31<00:00,  6.07s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 09, Train loss: 4.799097497879411, Val metrics: {'r2': 0.222708567290957, 'mae': 3.3450009892603196, 'rmse': 4.087353784712138}
# 100%|██████████| 15/15 [01:33<00:00,  6.26s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Epoch: 10, Train loss: 4.773377697915339, Val metrics: {'r2': 0.25790303129399395, 'mae': 3.2368057870195956, 'rmse': 3.993747635962485}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Best Val metrics: {'r2': 0.2598834228776551, 'mae': 3.2338101031546125, 'rmse': 3.9884151334134073}
# Best test metrics: {'r2': 0.09124557927366461, 'mae': 4.061267125522881, 'rmse': 4.9669881525428305}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
